# %% [markdown]
# <a href="https://colab.research.google.com/github/professor-rafael/Logica-de-programacao-fundamentos-e-desafios-em-Python/blob/main/l_gica_de_programa_o_fundamentos_e_desafios_em_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![ras.jpg.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # COMBINADOS
#
# **Vocês podem usar IA para:**
#
# ✅ Tirar dúvidas conceituais
#
# ✅ Pedir explicação de erro
#
# ✅ Pedir exemplos parecidos (não iguais)
#
# ✅ Pedir revisão depois que já terminaram
#
# **Vocês NÃO devem:**
#
# ❌ Pedir a solução completa
#
# ❌ Copiar código sem entender
#
# ❌ Colar o enunciado inteiro e pedir “resolve isso”

# %% [markdown]
# # Aula 1
# ## DESAFIO: DIVIDINDO AS BALAS
#
# Você comprou 13 balas e precisa dividir igualmente entre 4 amigos: Marcelo, Lucas, Felipe e Toni.
#
# Como a divisão deve ser feita em números inteiros, considere apenas a quantidade inteira de balas que cada um receberá.
#
# Descubra:
#
# * Quantas balas cada amigo vai receber?
#
# * Quantas balas vão sobrar?
#
#
# ---
# 📥 Entrada
#
# Um único número inteiro: 13 (Quantidade total de balas)
#
# 📤 Saída
#
# Dois números inteiros:
#
# 3
# 1
#
# ---
#
# Onde:
#
# 3 → quantidade de balas que cada amigo recebe
#
# 1 → quantidade de balas que sobram

# %%
print("Cada um dos meus amigos vão receber",27//4,"balas")
print("Vão/Vai sobrar", 27%4,"bala(s)")
# Out:
# Cada um dos meus amigos vão receber 6 balas
# Vão/Vai sobrar 3 bala(s)

# %% [markdown]
# # Aula 2
# ## DESAFIO: CALCULANDO UM PEDIDO
#
# Você está usando Python para melhorar o sistema de pedidos da cantina da sua escola.
#
# O suco custa R$ 5 e a cantina precisa de um programa simples para calcular o valor da compra.
#
# Sua missão é criar um programa que:
#
# * Pergunte quantos sucos a pessoa deseja
# * Calcule automaticamente o valor total
# * Mostre na tela quanto cada suco custa
# * Mostre o valor final da compra de forma clara
#
# ---
#
# 📥 Entrada
#
# Um número inteiro digitado pelo usuário, representando a quantidade de sucos desejados.
#
# Exemplo de entrada:
#
# 3
#
# 📤 Saída
#
# O preço de 1 suco é: R$ 5
#
# Quantidade de sucos: 3
#
# Valor total da compra: R$ 15
#
# ---
#
# Onde:
#
# R$ 5 → valor unitário do suco
#
# 3 → quantidade informada pelo usuário
#
# R$ 15 → valor total calculado (quantidade × 5)

# %%
quantidade = int(input("Quantos sucos você deseja?"))
suco = 5

print("O valor final dos sucos é R$",quantidade*suco, "reais")
# Out:
# Quantos sucos você deseja?100
# O valor final dos sucos é R$ 500 reais

# %% [markdown]
# # Aula 3
# ## DESAFIO: APLICANDO DESCONTOS
#
# Para melhorar o sistema da cantina da sua escola, foi criada uma promoção para quem compra hambúrgueres.
#
# Cada hambúrguer custa R$ 8.
#
# Existe uma promoção:
# Se a pessoa comprar **2 ou mais hambúrgueres**, ganha **R$ 2 de desconto no valor total** da compra.
#
# Sua missão é criar um programa que:
#
# * Pergunte quantos hambúrgueres a pessoa deseja
# * Calcule o valor total da compra
# * Verifique se a pessoa tem direito ao desconto usando `if`
# * Mostre o valor final com ou sem desconto de forma clara

# %%
quantidade = int(input("Quantos hambúrgueres você quer?"))
preco_hamburguer = 8
print("O preço final é R$", quantidade*preco_hamburguer)

if quantidade > 1: # >= 2
  print("Mas agora o preço com desconto é: ", quantidade*preco_hamburguer-2)
# Out:
# Quantos hambúrgueres você quer?2
# O preço final é R$ 16
# Mas agora o preço com desconto é:  14

# %% [markdown]
# # Aula 4
# ## DESAFIO: PEDIDO APROVADO OU NEGADO?
#
# Agora o programa precisa verificar se o estudante tem dinheiro suficiente para pagar o pedido.
#
# Um combo lanche custa **R$ 12**.
#
# Sua missão é criar um programa que:
#
# * Pergunte quanto dinheiro a pessoa tem
# * Compare esse valor com o preço do combo
# * Use `if` e `else` para decidir o que acontece
# * Mostre uma mensagem adequada para cada situação
#
# Se tiver dinheiro suficiente, mostrar algo como:
# “Pedido confirmado! Bom lanche”
#
# Se não tiver, mostrar algo como:
# “Saldo insuficiente. Junte mais dinheiro e volte depois.”

# %%
combo = 12
valor = float(input("Quanto você tem?"))

if valor < combo:
  print("Saldo insuficiente. Junte mais R$",combo-valor,"reais")
else:
  print("Pedido confirmado! Agora você tem um saldo de R$",valor-combo,"reais")
# Out:
# Quanto você tem? 4
# Saldo insuficiente. Junte mais R$ 8.0 reais

# %% [markdown]
# # Aula 5
# ## DESAFIO: CARDÁPIO DIGITAL
#
# A cantina da escola decidiu organizar melhor o sistema digital do cardápio.
#
# Todos os itens foram cadastrados em uma única lista, alternando entre comida e bebida:
#
# itens = ["pizza", "suco", "bolo", "refrigerante", "salgado", "água", "hamburguer", "café"]
#
# Sua missão é criar um programa que:
#
# * Mostre todos os itens do cardápio
# * Mostre apenas as comidas
# * Mostre apenas as bebidas
#
# ---
# Resultado final:
#
# Todos os itens do cardápio: ["pizza", "suco", "bolo", "refrigerante", "salgado", "água", "hamburguer", "café"]
#
# Cardápio de comida:  ['pizza', 'salgado', 'bolo', 'hamburguer']
#
# Cardápio de bebida: ['suco', 'refrigerante', 'água', 'café']

# %%
itens = ["pizza", # comida 0
         "suco", # bebida 1
         "bolo",  # comida  2
         "refrigerante", # bebida 3
         "salgado",  # comida 4
         "água",  # bebida 5
         "hamburguer",  # comida 6
         "café"] # bebida 7

# inicio : fim : passo
comida = itens[::2] # par
bebida = itens[1::2] # impar
print("Itens de comida do cardápio", comida)
print("Itens de bebida do cardápio", bebida)
# Out:
# Itens de comida do cardápio ['pizza', 'bolo', 'salgado', 'hamburguer']
# Itens de bebida do cardápio ['suco', 'refrigerante', 'água', 'café']

# %% [markdown]
# # Aula 6
# ## DESAFIO: ATUALIZANDO O CARDÁPIO
#
# A cantina da escola precisa atualizar o cardápio digital usando métodos de lista em Python.
#
# A lista inicial é:
#
# itens = ["pizza", "suco", "bolo"]
#
# Sua missão é criar um programa que:
#
# 1. Adicione "coxinha" ao final da lista
# 2. Insira "pastel" na primeira posição da lista
# 3. Remova o item "suco"
# 4. Remova o item que está na posição 2
# 5. No final, mostre todos os itens da lista
# 6. Verifique se tem algum item o que você quer comer no cardápio
#
# ---
#
# 📤 Saída
#
# Lista final:
# ['pastel', 'pizza', 'coxinha']
#
# Boas-vindas a cantina da escola! Qual item você quer? "Pizza"
#
# Pizza está no cardápio, que tal pedir?
#
# **ou:**
#
# Boas-vindas a cantina da escola! Qual item você quer? "bolo"
#
# bolo não está no cardápio, que tal você pedir? ['pastel', 'pizza', 'coxinha']

# %%
itens = ["pizza", "suco", "bolo"]

itens.append("coxinha")
itens.insert(0,"pastel")
itens.remove("suco")
itens.pop(2)

print(itens)
# Out:
# ['pizza', 'suco', 'bolo', 'coxinha']

# %%
print("Itens do cardápio", itens)
pedido = input("O que você quer comer hoje?")

if pedido in itens:
  print(pedido, "está no cardápio")
else:
  print(pedido, "não está no cardápio que tal você pedir", itens)
# Out:
# Itens do cardápio ['pastel', 'pizza', 'coxinha']
# O que você quer comer hoje?pastel
# pastel está no cardápio

# %% [markdown]
# # Aula 7
# ## DESAFIO: SOMANDO O VALOR DO CARDÁPIO
#
# A cantina quer calcular automaticamente o valor total de todos os itens disponíveis no cardápio.
#
# Os itens e seus respectivos preços estão organizados em duas listas:
#
# itens = ["pizza", "suco", "bolo", "refrigerante"]
# precos = [10, 5, 7, 8]
#
# Sua missão é criar um programa que:
#
# * Percorra as listas usando `for`
# * Mostre cada item com seu respectivo preço
# * Some todos os preços
# * Mostre o valor total do cardápio ao final
#
# ---
#
# 📤 Saída
#
# Item: pizza - Preço: R$ 10
#
# Item: suco - Preço: R$ 5
#
# Item: bolo - Preço: R$ 7
#
# Item: refrigerante - Preço: R$ 8
#
# Valor total do cardápio: R$ 30

# %%
itens = ["pizza", "suco", "bolo", "refrigerante"]
precos = [10, 5, 7, 8]
valor_final =0

for i in range(len(itens)):
  print(f"Item: {itens[i]} - Preço R$ {precos[i]}")
  valor_final += precos[i]
print(f"Valor total do cardápio R${valor_final}")
# Out:
# Item: pizza - Preço R$ 10
# Item: suco - Preço R$ 5
# Item: bolo - Preço R$ 7
# Item: refrigerante - Preço R$ 8
# Valor total do cardápio R$30

# %% [markdown]
# # Aula 8
# ## DESAFIO: FAZENDO UM PEDIDO NO CARDÁPIO DIGITAL
#
# A cantina da escola criou um sistema digital para que os alunos possam escolher vários itens do cardápio.
#
# Os itens e seus preços estão organizados em duas listas:
#
# itens = ["pizza", "suco", "bolo", "refrigerante"]
# precos = [10, 5, 7, 8]
#
# O sistema deve permitir que o aluno escolha vários itens até decidir finalizar o pedido digitando **-1**.
#
# Você precisa desenvolver um programa que:
#
# * Mostre o cardápio numerado com os preços
# * Permita que o usuário escolha itens pelo número
# * Some o valor de cada item escolhido
# * Use `while` para permitir múltiplas escolhas
# * Encerre o programa quando o usuário digitar **-1**
# * Mostre o valor total da compra ao final
#
# ---
#
# 📥 Entrada
#
# Exemplo de entradas digitadas:
#
# 0
# 2
# -1
#
# 📤 Saída
#
# ----- CARDÁPIO -----
#
# 0 - pizza (R$ 10)
#
# 1 - suco (R$ 5)
#
# 2 - bolo (R$ 7)
#
# 3 - refrigerante (R$ 8)
#
# -----------------------
# Exemplo:
#
# Escolha o número do item: 0
#
# pizza adicionado! Total parcial: R$ 10
#
# Escolha o número do item: 2
#
# bolo adicionado! Total parcial: R$ 17
#
# Escolha o número do item: -1
#
# Valor total da compra: R$ 17

# %%
itens = ["pizza", "suco", "bolo", "refrigerante"]
precos = [10, 5, 7, 8]

print("------CARDÁPIO------")
for i in range(len(itens)):
  print(f"{i} - {itens[i]} - R$ {precos[i]}")

print("--------------------")
valor_final =0
while True:
  escolha = int(input("Digite o número do item que você quer, caso queira sair, digite -1   "))

  if escolha == -1:
    break

  if 0<=escolha<=3:
    valor_final += precos[escolha]
    print(f"Item adicionado! valor parcial: R$ {valor_final}")

print(f"Valor total da compra: R$ {valor_final}")
# Out:
# ------CARDÁPIO------
# 0 - pizza - R$ 10
# 1 - suco - R$ 5
# 2 - bolo - R$ 7
# 3 - refrigerante - R$ 8
# --------------------
# Digite o número do item que você quer, caso queira sair, digite -1   0
# Item adicionado! valor parcial: R$ 10
# Digite o número do item que você quer, caso queira sair, digite -1   2
# Item adicionado! valor parcial: R$ 17
# Digite o número do item que você quer, caso queira sair, digite -1   3
# Item adicionado! valor parcial: R$ 25
# Digite o número do item que você quer, caso queira sair, digite -1   -1
# Valor total da compra: R$ 25

# %% [markdown]
# # Anotações

# %%
10+2
10-2
10*2
11//2
11%2
10/2
# Out:
# 5.0

# %%
type("Marcelo")
# Out:
# str

# %%
print("Meu nome é Marcelo e tenho ", 10+2, "anos de idade")
# Out:
# Meu nome é Marcelo e tenho  12 anos de idade

# %%
print(13//5)
print(13%5)
# Out:
# 2
# 3

# %%
balas = int(input("Quantas balas você quer?"))
pessoas = 5

print(balas//pessoas)
print(balas%pessoas)
# Out:
# Quantas balas você quer?15
# 3
# 0

# %%
type("10.0")
type(False)
type(True)
# Out:
# str

# %%
nota = 2


# nota > 6

# < menor que
# > maior que
# == igual
# != diferente
# <= menor igual
# >= maior igual

if nota < 6:
  print("Você foi reprovado")

if nota > 6:
  print("Você foi aprovado")
# Out:
# Você foi reprovado

# %%
nota = 2
if nota <= 6:
  print("aprovado")
else:
  print("você reprovou")
# Out:
# aprovado

# %%
nomes = ["Marcelo", "Jaspe", "Arnie","Naruto","Itachi"]
# print(nomes)
#nomes[1]
# inicio : fim : passo
nomes[::2]
# Out:
# ['Marcelo', 'Arnie', 'Itachi']

# %%
lista_nomes = ["Marcelo", "Laura", "Isabela", "Luana", "Guilherme", "Gabriel"]

lista_nomes.append("Maria")
print(lista_nomes)
# Out:
# ['Marcelo', 'Laura', 'Isabela', 'Luana', 'Guilherme', 'Gabriel', 'Maria']

# %%
# lista_nomes.append("João")
# lista_nomes.remove("João")
# lista_nomes.insert(0,"João")
# lista_nomes.pop(1)
print(lista_nomes)
"Guilherme" in lista_nomes
# Out:
# ['Marcelo', 'Gabriel', 'Maria']
# False

# %%
notas = [10,3,5,6,10,5,1,2]

# nota_final = notas[0] + notas[1] + notas[2] + notas[3]
nota_final = 0
for i in range(len(notas)):
  print(f"Nota {i+1} igual a  {notas[i]}")
  nota_final = nota_final + notas[i]

print(f"O valor final é de {nota_final}")
print(f"A média é: {nota_final/len(notas)}")
# Out:
# Nota 1 igual a  10
# Nota 2 igual a  3
# Nota 3 igual a  5
# Nota 4 igual a  6
# Nota 5 igual a  10
# Nota 6 igual a  5
# Nota 7 igual a  1
# Nota 8 igual a  2
# O valor final é de 42
# A média é: 5.25

# %%
# for i in range(10):
#   print(i)
i=0
while True:
  print(i)
  i = i+1
  escolha = int(input("digite -1 para sair"))
  if escolha == -1:
    break
# Out:
# 0
# digite -1 para sair1
# 1
# digite -1 para sair2
# 2
# digite -1 para sair3
# 3
# digite -1 para sair4
# 4
# digite -1 para sair5
# 5
# digite -1 para sair6
# 6
# digite -1 para sair-1
